# %%
import pandas as pd

# %% [markdown]
# # **Creating**

# %%
frame_num = {'Yes': [1, 2, 1, 1], 'No': [3, 4, 2, 1]}
frame_text = {'Saad': ['How are you?', 'I was your day?'], 'Husnain': ['I am Fine', 'Good']}
df_num = pd.DataFrame(frame_num)
df_text = pd.DataFrame(frame_text)
print(df_num)
print(df_text)
# Out:
#    Yes  No
# 0    1   3
# 1    2   4
# 2    1   2
# 3    1   1
#               Saad    Husnain
# 0     How are you?  I am Fine
# 1  I was your day?       Good

# %% [markdown]
# # **Analysis by Histogram**

# %%
df_num.hist('Yes')
df_num.hist('No')
# Out:
# array([[<Axes: title={'center': 'No'}>]], dtype=object)

# %% [markdown]
# Histogram fails with Non-Numerical Values:

# %%
df_text.hist('Saad')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0d405d67a04a> in <cell line: 1>()
# ----> 1 df_text.hist('Saad')
#       2 df_text.hist('Husnain')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     221     """
#     222     plot_backend = _get_plot_backend(backend)
# --> 223     return plot_backend.hist_frame(
#     224         data,
#     225         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     512
#     513     if naxes == 0:
# --> 514         raise ValueError(
# ...

# %% [markdown]
# # **Reading**

# %%
data_f = pd.DataFrame('/content/drive/MyDrive/Courses/Kaggle/Pandas/winemag-data-130k-v2.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-061f137af47a> in <cell line: 1>()
# ----> 1 data_f = pd.DataFrame('/content/drive/MyDrive/Courses/Kaggle/Pandas/winemag-data-130k-v2.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#
# ValueError: DataFrame constructor not properly called!
